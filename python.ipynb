# %% [markdown]
# <a href="https://colab.research.google.com/github/madisettyrangavijayalakshmi-create/c-programmings-/blob/main/python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("enter a value"))
b = int(input("enter b value"))
print("the sum is",a+b)
print("the sub is",a-b)
print("the mul",a*b)
print("the div",a/b)
print("the module",a%b)
print("the floor is",a//b)
print("the power of two numbers",a**b)
print(f"the sum of {a} and {b} is :",a+b)
# Out:
# enter a value200
# enter b value10
# the sum is 210
# the sub is 190
# the mul 2000
# the div 20.0
# the module 0
# the floor is 20
# the power of two numbers 102400000000000000000000
# the sum of 200 and 10 is : 210

# %%
kg = float (input("enter weight in kilograms:"))
pounds = kg*2.2
print("weight in pounds:",pounds)
# Out:
# enter weight in kilograms:55
# weight in pounds: 121.00000000000001

# %%
a = int(input("enter a value"))
b = int(input("enter b value"))
c = int(input("enter c value"))

total = a+b+c
average = total/3
print("the total is:",total)
print("the avreage is:",average)
# Out:
# enter a value20
# enter b value10
# enter c value10
# the total is: 40
# the avreage is: 13.333333333333334

# %%
r = int(input("enter radius"))
area = 3.14*r*r
print("the area of circle is:",area)
# Out:
# enter radius3
# the area of circle is: 28.259999999999998

# %%
import math as m
print(m.sqrt(25))
# Out:
# 5.0

# %%
for i in range(8, 90, 3):
 print(i, end=" ")
# Out:
# 8 11 14 17 20 23 26 29 32 35 38 41 44 47 50 53 56 59 62 65 68 71 74 77 80 83 86 89

# %%
for i in range(8,15):
 print(i, end=" ")
# Out:
# 8 9 10 11 12 13 14
